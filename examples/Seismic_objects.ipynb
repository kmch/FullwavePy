# %% [markdown]
# #### Notebook config

# %%
import numpy as np
import matplotlib.pyplot as plt
from plotea.mpl2d import *

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Generic

# %% [markdown]
# Add your own experiment by subclassing the abstract interface `Experiment`. See below for examples.

# %%
from fullwavepy.seismic.exp import Experiment
help(Experiment)
# Out:
# Help on class Experiment in module fullwavepy.seismic.exp:
#
# class Experiment(abc.ABC)
#  |  Helper class that provides a standard way to create an ABC using
#  |  inheritance.
#  |
#  |  Method resolution order:
#  |      Experiment
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Class methods defined here:
#  |
#  |  create(ID, *args, **kwargs) from abc.ABCMeta
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset({'_init_paths', '_init_segy_mapping'})
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from abc.ABC:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ## PROTEUS

# %%
from fullwavepy.seismic.proteus import PROTEUS
xp = PROTEUS()

# %% [markdown]
# ## Rainbow

# %%
from fullwavepy.seismic.rainbow import Rainbow

# %% [markdown]
# # Models

# %% [markdown]
# The `Mod` class is a container with handles to the associated array-object (of any dimensionality) and a file-object from which the array is read, if present.

# %% [markdown]
# ## Test-dev

# %%
class Mod:
    def __init__(self, arr, param='vp'):
        self.arr = arr
        self._init_param(param)

# %%
from fullwavepy.seismic.models import Mod

# %% [markdown]
# ## I/O

# %%
# Mod()

# %% [markdown]
# ### Reading from array

# %%
m = xp.svp

# %%
figure(20,10)
m.plot(1e3, axis=2, unit='m') # fixme labels don't show up

# %% [markdown]
# ### Reading from file

# %% [markdown]
# ## Plotting

# %% [markdown]
# ## Resampling

# %% [markdown]
# This is more challenging than a generic array as it has sharp interfaces.

# %% [markdown]
# ## Shearing

# %% [markdown]
# See `074_...ipynb`.

# %% [markdown]
# ## Air layer

# %% [markdown]
# ## Anomalies

# %% [markdown]
# # Surfaces

# %% [markdown]
# ### Old-ish API

# %% [markdown]
# #### Alg.
# Create a rotated plane.

# %%
from lib_fwi_fs import FS_Create
fs = FS_Create('s01', pars_gen=dict(dims=(30,30,30)), pars_FS=dict(fs_type='rotated'))
plt.imshow(fs[..., 0].T)

# %% [markdown]
# # ...
